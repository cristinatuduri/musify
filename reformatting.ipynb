# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/cristinatuduripoza/Downloads/noras_playlist.csv',index_col=[0])
df_big = pd.read_csv('/Users/cristinatuduripoza/Downloads/puf.csv')

# %%
df.head()
# Out:
#                                                            Artist IDs  \
# Spotify ID
# 3AZXqe3LGCFD4r6YFJgaK3                         4VMYDCV2IEDYJArk749S6m
# 3Kemg5QPEhEjOiWUFrTkXX  4VMYDCV2IEDYJArk749S6m,1SupJlEpv7RS2tPNRaHViT
# 2cRtuTadVm0JzoW4NNTIqI                         2jSGzJw0ebJLu7OLVSOcBP
# 419w8oZaqevgyZfdvFZEHa  3ptY5WTxu77JpAQQnHyxEl,7hIqJfRYGBWWT1Qxu6Cpd2
# 7fZJWsOEdr8aP8okxyTBGd  52wHLjXBRtdLP9VXX4Uosn,6bwz9tsKnEgaWbwGobFWQR
#
#                                                               Track Name  \
# Spotify ID
# 3AZXqe3LGCFD4r6YFJgaK3                                   Ella Me Levanto
# 3Kemg5QPEhEjOiWUFrTkXX           Donde Estan Las Gatas (feat. Nicky Jam)
# 2cRtuTadVm0JzoW4NNTIqI                                             Candy
# 419w8oZaqevgyZfdvFZEHa                             Te Pintaron Pajaritos
# 7fZJWsOEdr8aP8okxyTBGd  La conocí bailando (feat. K-Narias) - Radio Edit
#
#                                                  Album Name  \
# Spotify ID
# ...

# %%
df2 = df.rename(columns = {
                'Artist IDs': 'artists_id', 
                'Track Name': 'track_name',
                'Album Name_y': 'album_name', 
                'Artist Name(s)_y': 'artist_name_s',
                'Release Date': 'date',
                'Duration (ms)': 'duration_ms', 
                'Added By_y': 'added_by', 
                'Added At_y': 'added_at', 
                'Time Signature':'time_signature', 
                'Popularity_y':'song_popularity', 
                'Genres': 'genres', 
                'Danceability': 'danceability', 
                'Energy':'energy', 
                'Key': 'key', 
                'Loudness':'loudness', 
                'Mode': 'mode', 
                'Speechiness':'speechiness', 
                'Acousticness':'acousticness', 
                'Instrumentalness': 'instrumentalness', 
                'Liveness': 'liveness', 
                'Valence':'valence', 
                'Tempo': 'tempo', 
                'Track URI':'track_uri',
                'Artist URI(s)': 'artist_uris', 
                'Album URI': 'album_uri', 
                'Album Artist URI(s)': 'album_artist_uris', 
                'Album Artist Name(s)':'album_artist_names', 
                'Album Release Date':'album_date',
                'Album Image URL':'album_img_url', 
                'Disc Number':'disc_number',
                'Track Number': 'track_number', 
                'Track Preview URL':'track_preview_url', 
                'Explicit':'explicit', 
                'ISRC':'isrc'
                })

# %%
df3 = df_big.rename(columns = {
                'Artist IDs': 'artists_id', 
                'Track Name': 'track_name',
                'Album Name': 'album_name', 
                'Artist Name(s)': 'artists',
                'Release Date': 'date',
                'Duration (ms)': 'duration_ms', 
                'Added By': 'added_by', 
                'Added At': 'added_at', 
                'Time Signature':'time_signature', 
                'Popularity':'song_popularity', 
                'Genres': 'genres', 
                'Danceability': 'danceability', 
                'Energy':'energy', 
                'Key': 'key', 
                'Loudness':'loudness', 
                'Mode': 'mode', 
                'Speechiness':'speechiness', 
                'Acousticness':'acousticness', 
                'Instrumentalness': 'instrumentalness', 
                'Liveness': 'liveness', 
                'Valence':'valence', 
                'Tempo': 'tempo'})

# %%
df3.shape
# Out:
# (732, 23)

# %%
df3.to_csv('/Users/cristinatuduripoza/Downloads/big.csv', index=True)

# %%
df2.columns

df2.drop(columns = ['Track Duration (ms)'])
# Out:
#                                 track_uri  \
# 0    spotify:track:3AZXqe3LGCFD4r6YFJgaK3
# 1    spotify:track:3Kemg5QPEhEjOiWUFrTkXX
# 2    spotify:track:2cRtuTadVm0JzoW4NNTIqI
# 3    spotify:track:419w8oZaqevgyZfdvFZEHa
# 4    spotify:track:7fZJWsOEdr8aP8okxyTBGd
# ..                                    ...
# 595  spotify:track:15h9quQgltWsgYsdqSyPNb
# 596  spotify:track:15h9quQgltWsgYsdqSyPNb
# 597  spotify:track:1VB4sadHjFcFklHcZuoROi
# 598  spotify:track:7mitXLIMCflkhZiD34uEQI
# 599  spotify:track:1DxEbt6OSbrkRthk6pjZue
#
#                                            track_name  \
# 0                                     Ella Me Levanto
# 1             Donde Estan Las Gatas (feat. Nicky Jam)
# 2                                               Candy
# 3                               Te Pintaron Pajaritos
# 4    La conocí bailando (feat. K-Narias) - Radio Edit
# ..                                                ...
# 595                                Mi Estrella Blanca
# ...

# %%
df2['date'] = pd.to_datetime(df2['date'], errors='coerce')

# Check for any NaT values which indicate conversion issues
print(df2[df2['date'].isna()])
# Out:
#                                 track_uri  \
# 18   spotify:track:6G5GbFe5jWUWqZ3WmXiew5
# 195  spotify:track:7pYfyrMNPn3wtoCyqcTVoI
# 452  spotify:track:1CLf6VyiREgwjpr8ol73TI
#
#                                             track_name  \
# 18                  Follow the Leader "Sigue al lider"
# 195  Moves Like Jagger - Studio Recording From "The...
# 452                                                NaN
#
#                                            artist_uris  \
# 18               spotify:artist:48OR7mEuKftuWNjx2qWzFC
# 195  spotify:artist:04gDigrS5kc9YWfZHwBETP, spotify...
# 452              spotify:artist:0LyfQWJT6nXafLPZqxe9Of
#
#                                 album_uri  \
# 18   spotify:album:1E3jBTndyToLyM4QVuUP1b
# 195  spotify:album:1snrPQMoTrBsKl73wzSxbn
# 452  spotify:album:5KTIDQspYXv0lbEb6ohhak
#
#                          album_artist_uris album_artist_names  album_date  \
# 18   spotify:artist:0LyfQWJT6nXafLPZqxe9Of    Various Artists  2010-08-16
# ...

# %%
df2['date'] = pd.to_datetime(df2['date'], format='%Y-%m-%d', errors='raise')
df2 = df2.dropna()

# %%
df2.head()
# Remove the 'spotify:track:' prefix
# Out:
#                               track_uri  \
# 0  spotify:track:3AZXqe3LGCFD4r6YFJgaK3
# 1  spotify:track:3Kemg5QPEhEjOiWUFrTkXX
# 2  spotify:track:2cRtuTadVm0JzoW4NNTIqI
# 3  spotify:track:419w8oZaqevgyZfdvFZEHa
# 4  spotify:track:7fZJWsOEdr8aP8okxyTBGd
#
#                                          track_name  \
# 0                                   Ella Me Levanto
# 1           Donde Estan Las Gatas (feat. Nicky Jam)
# 2                                             Candy
# 3                             Te Pintaron Pajaritos
# 4  La conocí bailando (feat. K-Narias) - Radio Edit
#
#                                          artist_uris  \
# 0              spotify:artist:4VMYDCV2IEDYJArk749S6m
# 1  spotify:artist:4VMYDCV2IEDYJArk749S6m, spotify...
# 2              spotify:artist:2jSGzJw0ebJLu7OLVSOcBP
# 3  spotify:artist:3ptY5WTxu77JpAQQnHyxEl, spotify...
# 4  spotify:artist:52wHLjXBRtdLP9VXX4Uosn, spotify...
#
#                               album_uri  \
# ...

# %%
df2.to_csv('/Users/cristinatuduripoza/Downloads/norette.csv', index=True)
